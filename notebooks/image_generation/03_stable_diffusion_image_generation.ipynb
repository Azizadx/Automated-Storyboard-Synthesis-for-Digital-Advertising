# %%
import os
import sys
from IPython.display import Image
import io
import base64

sys.path.append(os.path.abspath(os.path.join('../../scripts')))

# %%
from image_generator.image_generator_with_stable_diffusion import ImageTextModel

# %%
image_text_model = ImageTextModel()
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
# Generate images from text
images = image_text_model.generate_images_from_text("photograph of an astronaut riding a horse")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/miniconda/lib/python3.11/site-packages/tensorflow/python/ops/array_ops.py:5238, in gather(***failed resolving arguments***)
#    5235 try:
#    5236   # TODO(apassos) find a less bad way of detecting resource variables
#    5237   # without introducing a circular dependency.
# -> 5238   return params.sparse_read(indices, name=name)
#    5239 except AttributeError:
#
# File /opt/miniconda/lib/python3.11/site-packages/tensorflow/python/framework/tensor.py:261, in Tensor.__getattr__(self, name)
#     256   raise AttributeError(
#     257       f"{type(self).__name__} object has no attribute '{name}'. " + """
#     258     If you are looking for numpy-related methods, please run the following:
#     259     tf.experimental.numpy.experimental_enable_numpy_behavior()
#     260   """)
# --> 261 self.__getattribute__(name)
#
# ...

# %%
image_text_model.plot_images(images)

# %%
prompt = "Background: A high-resolution 3D Coca-Cola bottle center-screen, bubbles rising to the top, transitioning into a sleek DJ turntable withImageGenerater a vinyl record that has the Coke Studio logo"

# %%
# Generate images from text
images = image_text_model.generate_images_from_text(prompt)
# Out:
# 50/50 [==============================] - 812s 15s/step

# %%
image_text_model.plot_images(images)
